# %%
import sys
sys.path.insert(0, str(__import__('pathlib').Path().resolve().parent))

from modules.read_save import read_json
import os
from path import Path

# %%
path = Path(os.getcwd()).parent.parent / "data" / "filter" / "filter.json"
mask, mask_size, function, stride, dilatation_rate, activation_function = read_json(path)

print(mask, mask_size, function, stride, dilatation_rate, activation_function )
# Out:
# [[1, 1, 1], [1, 1, 1], [1, 1, 1]] (3, 3) box 10 1
